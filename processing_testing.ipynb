# %%
from proj1_helpers import load_csv_data, predict_labels
from implementation import least_squares
from helpers import split_data
from helpers import build_poly
from data_process import impute, normalization

from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
yb_data_train, input_data_train, ids_train = load_csv_data("Data/train.csv", sub_sample = True)
#yb_data_test, input_data_test, ids_test = load_csv_data("Data/test.csv")

# %%
x = impute(input_data_train)
x = normalization(x)

# %%
a = np.delete(x, [5,6,12,26], axis = 1)

# %%
a.shape
# Out:
# (5000, 26)

# %%
#pca = PCA()

# %%
#x = pca.fit_transform(x,1)

# %%
#sns.pairplot(x.loc[:,0:5])
#sns.heatmap(x.corr(), annot = True)

# %%
# f = plt.figure(figsize=(19, 15))
# plt.matshow(x.corr(), fignum=f.number)
# plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
# plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
# cb = plt.colorbar()
# cb.ax.tick_params(labelsize=14)
# plt.title('Correlation Matrix', fontsize=16);

# %%
x
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.336722  0.039654  0.406516 -0.465892 -1.371337 -0.629736  1.580862
# 1     1.813392  0.633441  1.059255 -0.823694 -0.088551 -0.192789  0.071148
# 2    -0.536761 -0.641519 -0.377843 -0.020143 -0.088551 -0.192789  0.071148
# 3     0.147930  0.053639  0.142719  0.734419 -1.381894 -0.977635  2.664214
# 4    -0.238704 -1.379200 -0.255286 -0.041748 -0.088551 -0.192789  0.071148
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995  0.172759  0.240741  0.339062  0.365393 -0.839218 -0.160141  3.131037
# 4996 -0.409300  0.584467 -0.178213 -0.119664 -2.321548 -0.779404  0.759497
# 4997  0.407764 -1.223661  0.439989  0.643560 -0.088551 -0.192789  0.071148
# 4998 -0.768358 -0.112174 -0.504413 -0.651464 -0.088551 -0.192789  0.071148
# 4999  0.182288 -1.318297 -0.318728 -0.097088 -0.088551 -0.192789  0.071148
#
#             7         8         9   ...        20        21        22  \
# 0     0.869137  1.031040  0.341158  ... -0.169179  0.381946  1.041459
# 1     1.761905  1.255999 -0.299234  ...  0.515490 -0.921115  0.015997
# 2     0.102644  0.073347 -0.165305  ...  0.471210  0.077080  0.015997
# 3    -0.124652 -0.765398  0.467440  ...  1.535021  0.643900  1.041459
# 4    -0.374678  0.511676 -0.057616  ...  0.642793  0.625458  0.015997
# ...        ...       ...       ...  ...       ...       ...       ...
# 4995  0.295846 -0.476967  1.267310  ...  0.423610  1.338458  1.041459
# 4996  0.644366  1.596088  0.293284  ... -1.642019 -0.707954  1.041459
# 4997 -0.440341 -0.778110  0.596129  ... -0.104974  0.169892  0.015997
# 4998 -0.032471  0.105285 -0.659495  ... -0.063462 -0.433850  0.015997
# 4999  0.208716 -0.808835 -0.297975  ...  0.259223 -0.538016  0.015997
#
#             23        24        25        26        27        28        29
# 0    -0.198679  1.547162  0.326886 -0.214936  1.169914 -2.362721  0.398182
# 1    -0.548111 -0.503151 -0.446193 -0.169473 -0.013879 -0.014670 -0.231796
# 2    -0.294430  0.562897 -1.561675 -0.169473 -0.013879 -0.014670 -0.108298
# 3    -0.096735 -1.924309 -0.199178 -1.003340 -1.591663 -0.133855  0.299953
# 4    -0.215106 -0.252780 -0.334431 -0.169473 -0.013879 -0.014670 -0.069682
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995  1.329522 -1.278654 -2.013705  0.430108 -2.882162  0.740171  1.263116
# 4996 -0.426562 -0.731282 -2.136145 -0.004393 -0.886676  1.431853  0.326729
# 4997  0.409029  1.691358 -1.246322 -0.169473 -0.013879 -0.014670  0.234161
# 4998 -0.916349  2.092381  1.020948 -0.169473 -0.013879 -0.014670 -0.411063
# 4999 -0.534966 -2.392767 -2.194517 -0.169473 -0.013879 -0.014670 -0.225397
#
# [5000 rows x 30 columns]

# %%
corr = x.corr()
corr.loc[:,21:30][corr > .6]
# Out:
#           21        22        23   24   25        26   27   28        29
# 0        NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 1        NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 2        NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 3   0.782805  0.611497  0.773126  NaN  NaN       NaN  NaN  NaN  0.808407
# 4        NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 5        NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 6        NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 7        NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 8        NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 9   0.905552  0.749489  0.809798  NaN  NaN  0.632810  NaN  NaN  0.971070
# 10       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 11       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 12       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 13       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 14       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 15       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 16       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 17       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 18       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 19       NaN       NaN  0.618705  NaN  NaN       NaN  NaN  NaN       NaN
# 20       NaN       NaN       NaN  NaN  NaN       NaN  NaN  NaN       NaN
# 21  1.000000  0.692746  0.725191  NaN  NaN       NaN  NaN  NaN  0.886090
# 22  0.692746  1.000000       NaN  NaN  NaN       NaN  NaN  NaN  0.786039
# 23  0.725191       NaN  1.000000  NaN  NaN       NaN  NaN  NaN  0.807791
# 24       NaN       NaN       NaN  1.0  NaN       NaN  NaN  NaN       NaN
# 25       NaN       NaN       NaN  NaN  1.0       NaN  NaN  NaN       NaN
# 26       NaN       NaN       NaN  NaN  NaN  1.000000  NaN  NaN  0.671581
# 27       NaN       NaN       NaN  NaN  NaN       NaN  1.0  NaN       NaN
# 28       NaN       NaN       NaN  NaN  NaN       NaN  NaN  1.0       NaN
# 29  0.886090  0.786039  0.807791  NaN  NaN  0.671581  NaN  NaN  1.000000

# %%
x = x.drop([5,6,12,26,27,28],axis=1) #column 4 stays
x = x.drop([21,29], axis = 1) #column 9 stays

# %%
#x = x.where(x > -999)

# %%
#x.isna().sum(axis=0)

# %%
#x = x.dropna(axis = 1, thresh = 175000)

# %%
#x[x <= -998] = np.nan

# %%
#nan_count =[]
#for col in x.T:
#    nan_count.append(np.count_nonzero(np.isnan(col)))

# %%
#x = x.fillna(-999)

# %%
x = x.to_numpy()

# %%
x, l = build_poly(x, 3)

# %%
x
# Out:
# array([[  1.        ,   0.33672191,   0.03965436, ...,   0.78246928,
#           0.16532081,   0.03492913],
#        [  1.        ,   1.81339228,   0.63344061, ...,  -0.11295855,
#          -0.10017126,  -0.08883153],
#        [  1.        ,  -0.5367614 ,  -0.64151886, ...,  -0.49482101,
#           1.37280861,  -3.80865697],
#        ...,
#        [  1.        ,   0.40776378,  -1.22366112, ...,  -3.56534137,
#           2.62721562,  -1.93593297],
#        [  1.        ,  -0.76835752,  -0.11217409, ...,   4.46976957,
#           2.18096063,   1.06416879],
#        [  1.        ,   0.18228785,  -1.31829705, ..., -12.56434694,
#         -11.52334067, -10.56858593]])

# %%
x_train, y_train, x_test, y_test = split_data(x, yb_data_train, .8)

# %%
w, rmse = least_squares(y_train, x_train)

# %%
y_pred = predict_labels(w, x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.688

# %%
f1_score(y_test, y_pred)
# Out:
# 0.5272727272727273
